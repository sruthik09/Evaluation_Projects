# %% [markdown]
# # Baseball Case Study
# Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.
#
# Downlaod Files:
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# #### Obsevation:
#          Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed,
#                          Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors.
#
#          Output: Number of predicted wins (W)

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# #### Observation: All the features are numerical.

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data Visualization:

# %% [markdown]
# Lets see how data is distributed for every column in our dataset:
# Before that lets split our dataset into Nominal , Ordinal & Continuous , dicsrete data, before we plot the graphs.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# #### Observation: For the given dataset, we have continuous and discrete data.

# %% [markdown]
# ### Making a DataFrame of Continuous data

# %%
df_visualization_continuous = df[['ERA']].copy()
df_visualization_continuous.columns
# Out:
# Index(['ERA'], dtype='object')

# %%
df_visualization_continuous.dtypes
# Out:
# ERA    float64
# dtype: object

# %%
# Visualization of continuous data
import seaborn as sns
sns.distplot(df_visualization_continuous['ERA'], kde = True)

# %% [markdown]
# ### Making a DataFrame of Discrete data

# %%
df_visualization_discrete = df[['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
                                'CG', 'SHO', 'SV', 'E']].copy()
df_visualization_discrete.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# Visualization of discrete data
df_visualization_discrete.hist(color = 'y', figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8F7AB1C88>,
# ...
#       dtype=object)

# %%
# Visulaizing distribution of features using Dist Plot:

plt.figure(figsize = (20,20), facecolor = 'white')
plotnumber = 1   #initializing 1 to a name

for column in df_visualization_discrete:
    if plotnumber <= 15:
        ax = plt.subplot(3,5,plotnumber) #In 3 rows I want 5 columns to be plotted 
        sns.distplot(df_visualization_discrete[column])
        plt.xlabel(column,fontsize = 20)
        plotnumber += 1
        plt.tight_layout()

# %% [markdown]
# #### Observation: Almost all the features are skewed.

# %% [markdown]
# # Checking for nulls

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# #### Observation: There are no nulls present in any feature . Good to proceed.

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Statistical Summary

# %%
#Describe the dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# #### Observation of .describe(): Count is same in all the columns. means no NaN's.
#
# the above table that for most of attributes Mean and Median (50%) is approximatly same
#
# Most of attributes data are normally distributed.
#
# some attributes such as 'H','HR', Mean value is greater than Median value which means data is right skewed in Nature
#
# possiblity of outliers are very less in our dataset.

# %%
#Heatmap using df.describe

import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(), annot=True, linewidths=0.1, linecolor='black',fmt=".2f")

# %% [markdown]
# # checking the correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#Heatmap using df.corr

plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor='black',fmt="0.2f")

# %%
sns.relplot(x='R',y='W', data= df)

# %%
sns.lineplot(x='R',y='W', data= df)

# %%
sns.scatterplot(x='R',y='W', data= df)

# %%
#Scatter plot finds relationship between features and y.


x = df.iloc[:, 1:]
y = df.iloc[:, :1]

plt.figure(figsize = (20,20), facecolor= 'white')
plotnumber = 1

for column in x:
    if plotnumber<=16:
        ax = plt.subplot(4,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize = 10)
        plt.ylabel('W', fontsize = 10)
        plotnumber += 1
        plt.tight_layout()

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='r')

# %%
df.corr()['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# ### Outcome of correlation: with 'W'
#
#
# the features 'SV','BB','SHO','R','2B','HR','SO','CG','H' are positively correlated with our label 'W' , &
# the features 'AB','E','SB','3B','ER','RA','ERA' are negatively correlated with our label 'W'.
#
# R   0.43     43%  -> Strong bond ;
# AB -0.09     9 %  -> Weak bond ;
# H   0.04     4 %  -> Weak bond ;
# 2B  0.43     43%  -> Strong bond ;
# 3B -0.25     25%  -> Strong bond ;
# HR  0.31     31%  -> Strong bond ;
# BB  0.48     48%  -> Strong bond ;
# SO  0.11     11%  -> Good bond ;
# SB -0.16     16%  -> Good bond ;
# RA -0.81     81%  -> Strong bond ;
# ER -0.81     81%  -> Strong bond ;
# ERA-0.82     82%  -> Strong bond ;
# CG  0.08     8 %  -> Weak bond ;
# SHO 0.47     47%  -> Strong bond ;
# SV  0.67     67%  -> Strong bond ;
# E  -0.09     9 %  -> Strong bond ;
#
#
#
# Max Correlation: SV &
# Min Correlation: H
#
#
# SV,BB,SHO these are important features which are positivly correlated to our Target Attribute Wins.
#
# ERA,RA,ER these are the features which are highly negatively correlated to our target attribute.
#
# Feature like H,AB has correlation value near to zero which means almost no significance for target attribute prediction.

# %% [markdown]
# # Skewness:

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# We see skewness in few columns.

# %%
#Dividing into features and label
x = df.iloc[:, 1:]
y = df.iloc[:, :1]
x.head(5)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %% [markdown]
# # power transform function

# %%
# we will remove the skewness using power_tranform function
from sklearn.preprocessing import power_transform
x_new = power_transform(x ,  method = 'yeo-johnson')
x = pd.DataFrame(x_new,columns=x.columns)
x.head()
# Out:
#      R   AB    H        2B        3B        HR        BB        SO        SB  \
# 0  0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1  0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2  0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3  0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4  0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
#
#          RA        ER       ERA        CG       SHO        SV         E
# 0 -0.660331 -0.497425 -0.500893 -0.359844 -0.789579  1.546378 -0.334953
# 1  0.175465  0.257974  0.261806 -0.359844  0.251775  0.360444 -0.532211
# 2 -0.674621 -0.746906 -0.636459  1.993513 -0.245393 -0.607594 -1.342331
# 3  0.189512  0.113575  0.060804  1.220103 -0.510759 -0.764453  0.678524
# 4  1.603228  1.582654  1.520959  1.220103  0.251775 -1.095010 -0.532211

# %%
x.skew()
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# RA    -0.008082
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %% [markdown]
# Skewness is now handled.Good to proceed. Also, R,AB,H has 0 skewness, which means perfectly symmetrical.

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled= sc.fit_transform(x)
x = pd.DataFrame(x_scaled, columns= x.columns)
x.head()
# Out:
#      R   AB    H        2B        3B        HR        BB        SO        SB  \
# 0  0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1  0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2  0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3  0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4  0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
#
#          RA        ER       ERA        CG       SHO        SV         E
# 0 -0.660331 -0.497425 -0.500893 -0.359844 -0.789579  1.546378 -0.334953
# 1  0.175465  0.257974  0.261806 -0.359844  0.251775  0.360444 -0.532211
# 2 -0.674621 -0.746906 -0.636459  1.993513 -0.245393 -0.607594 -1.342331
# 3  0.189512  0.113575  0.060804  1.220103 -0.510759 -0.764453  0.678524
# 4  1.603228  1.582654  1.520959  1.220103  0.251775 -1.095010 -0.532211

# %% [markdown]
# # Checking important features

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra=ExtraTreesClassifier()
extra.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(extra.feature_importances_)
# Out:
# [0.         0.         0.         0.08904947 0.06643066 0.0753039
#  0.06891773 0.06863684 0.0862594  0.09356191 0.07240281 0.07925435
#  0.06897616 0.066108   0.07321404 0.09188474]

# %%
plt.figure(figsize=(15,6))
plt.title('Important Features',fontsize=15)
feat_importance=pd.Series(extra.feature_importances_,index=x.columns)
feat_importance.nlargest(10).plot(kind='barh')
plt.show();

# %% [markdown]
# #### Observation: SB,2B,E are the most important Features for prediction of Number of win counts for our Machine Learning Model

# %% [markdown]
# # Checking Outliers:

# %%
#plotting boxplot for all the columns
x.iloc[:,0:16].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# # Outliers Removal

# %% [markdown]
# ## Z Score Technique:

# %%
from scipy.stats import zscore
import numpy as np 
z=np.abs(zscore(x))
z.shape
# Out:
# (30, 16)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df_new=x[(z<3).all(axis=1)]
print(x.shape)
print(df_new.shape)
# Out:
# (30, 16)
# (0, 16)

# %% [markdown]
# Means no sinificant outliers to be removed. Means theres no data loss.

# %% [markdown]
# ## Finding Best Random_state:

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet, LassoCV,RidgeCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()

for i in range (0,1000):
    features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    if round(r2_score(target_train,pred_train)*100,1)==round(r2_score(target_test,pred_test)*100,1):
        print(f"At random state {i}, The model performs very well")
        
        print(f"At random state {i}, the training accuracy is:- {r2_score(target_train,pred_train)*100}")
        print(f"At random state {i}, the testing accuracy is:- {r2_score(target_test,pred_test)*100}")
        print("\n")
# Out:
# At random state 349, The model performs very well
# At random state 349, the training accuracy is:- 86.8485804905106
# At random state 349, the testing accuracy is:- 86.84292025690164

# %%
features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=0.2,random_state=349)

# %%
lr = LinearRegression()

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',lr.score(features_train,target_train)*100)
print('Test Accuracy',lr.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(lr,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
print('\n')
# Out:
# ACCURACY
# Training accuracy 86.8485804905106
# Test Accuracy 86.84292025690164
# -------------------------------
#
#
# SCORES
# r2_score 0.8684292025690163
# cross validation score -142.28754457348055
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 2.643244747469616
# MSE 11.958323588727174
# RMSE 3.458080911246464

# %% [markdown]
# We expect our scores to be high and evaluation(error) metrics to be low.

# %% [markdown]
# # Regularization with Lasso , Ridge

# %% [markdown]
# # Lasso
# LassoCV returns the best alpha after max iteration.

# %%
lassCV = LassoCV(alphas=None, max_iter=100, normalize=True)

# %%
lassCV.fit(features_train, target_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
#best alpha parameter, if we use this learning rate, our lasso model will learn at best possible rate.
alpha = lassCV.alpha_
alpha
# Out:
# 0.22759403821669796

# %%
#Training the Lasso regressor with best learning rate 'alpha'
lasso_reg = Lasso(alpha)

# %%
lasso_reg.fit(features_train,target_train)
# Out:
# Lasso(alpha=0.22759403821669796)

# %%
pred_test = lasso_reg.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',lasso_reg.score(features_train,target_train)*100)
print('Test Accuracy',lasso_reg.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(lasso_reg,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
# Out:
# ACCURACY
# Training accuracy 85.01573099815062
# Test Accuracy 72.59985408328107
# -------------------------------
#
#
# SCORES
# r2_score 0.7259985408328107
# cross validation score 15.661574967166992
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 4.038965828663298
# MSE 24.903688177640092
# RMSE 4.990359523886039

# %% [markdown]
# Our lasso testing score is 72.59, whereas our LinearRegression testing score is 86.84 , means our LinearRegression is
# overfitting.

# %% [markdown]
# # Ridge
# RidgeCV returns best alpha  and coefiicients after performing 10 cross validations.

# %%
ridgeCV = RidgeCV(alphas = np.arange(0.001,0.1,0.01), normalize=True)  #forcing our ridgeCV to get best learning parameter from this specified range
ridgeCV.fit(features_train,target_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
#best alpha parameter, if we use this learning rate, our ridge model will learn at best possible rate.
ridgeCV.alpha_
# Out:
# 0.09099999999999998

# %%
#Training the Ridge regressor with best learning rate 'alpha'
ridge_reg = Ridge(alpha=ridgeCV.alpha_)

# %%
ridge_reg.fit(features_train,target_train)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
pred_test = lasso_reg.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',ridge_reg.score(features_train,target_train)*100)
print('Test Accuracy',ridge_reg.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(ridge_reg,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
# Out:
# ACCURACY
# Training accuracy 86.48517810424221
# Test Accuracy 84.92809216635449
# -------------------------------
#
#
# SCORES
# r2_score 0.7259985408328107
# cross validation score -5.586474162609707
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 4.038965828663298
# MSE 24.903688177640092
# RMSE 4.990359523886039

# %% [markdown]
# # Decision Tree Regressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(features_train,target_train)
# Out:
# DecisionTreeRegressor()

# %%
pred_test = dt.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',dt.score(features_train,target_train)*100)
print('Test Accuracy',dt.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(dt,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
# Out:
# ACCURACY
# Training accuracy 100.0
# Test Accuracy 32.885085574572116
# -------------------------------
#
#
# SCORES
# r2_score 0.32885085574572115
# cross validation score -245.40839187164525
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 7.333333333333333
# MSE 61.0
# RMSE 7.810249675906654

# %% [markdown]
# # KNN Regressor

# %%
knn=KNeighborsRegressor()

# %%
knn.fit(features_train,target_train)
# Out:
# KNeighborsRegressor()

# %%
pred_test = knn.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',knn.score(features_train,target_train)*100)
print('Test Accuracy',knn.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(knn,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
# Out:
# ACCURACY
# Training accuracy 68.19762960574054
# Test Accuracy 31.22738386308066
# -------------------------------
#
#
# SCORES
# r2_score 0.3122738386308066
# cross validation score -29.35514317270694
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 6.533333333333334
# MSE 62.50666666666668
# RMSE 7.90611577619925

# %% [markdown]
# # SVM Regressor

# %%
svm=SVR()

# %%
svm.fit(features_train,target_train)
# Out:
# SVR()

# %%
pred_test = svm.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',svm.score(features_train,target_train)*100)
print('Test Accuracy',svm.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(svm,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
print('\n')
# Out:
# ACCURACY
# Training accuracy 24.97798892984421
# Test Accuracy 4.183141491692233
# -------------------------------
#
#
# SCORES
# r2_score 0.04183141491692233
# cross validation score -40.707289455953976
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 7.514510467653518
# MSE 87.08687806643972
# RMSE 9.332035044214082

# %% [markdown]
# # Ensemble Technique

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# # Random Forest Regressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(features_train,target_train)
# Out:
# RandomForestRegressor()

# %%
pred_test = rf.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',rf.score(features_train,target_train)*100)
print('Test Accuracy',rf.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(rf,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
print('\n')
# Out:
# ACCURACY
# Training accuracy 92.0003315326937
# Test Accuracy 58.80457212713939
# -------------------------------
#
#
# SCORES
# r2_score 0.5880457212713939
# cross validation score -76.24397506297565
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 4.743333333333332
# MSE 37.44206666666665
# RMSE 6.118992291763951

# %% [markdown]
# # Ada Boost Regressor

# %%
lasso = Lasso()

# %%
Adb=AdaBoostRegressor(base_estimator=lasso)

# %%
Adb.fit(features_train,target_train)
# Out:
# AdaBoostRegressor(base_estimator=Lasso())

# %%
pred_test = Adb.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',Adb.score(features_train,target_train)*100)
print('Test Accuracy',Adb.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(Adb,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
print('\n')
# Out:
# ACCURACY
# Training accuracy 83.8223064324549
# Test Accuracy 70.81878733022695
# -------------------------------
#
#
# SCORES
# r2_score 0.7081878733022695
# cross validation score 5.034136719545712
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 4.172409164353783
# MSE 26.522479959860387
# RMSE 5.1499980543550095

# %% [markdown]
# # Gradient Boost

# %%
gnb=GradientBoostingRegressor()

# %%
gnb.fit(features_train,target_train)
# Out:
# GradientBoostingRegressor()

# %%
pred_test = gnb.predict(features_test)

# %%
print('\n')
print('ACCURACY')
print('Training accuracy',gnb.score(features_train,target_train)*100)
print('Test Accuracy',gnb.score(features_test,target_test)*100)    

print('-------------------------------')
print('\n')

print('SCORES')
print('r2_score',r2_score(target_test,pred_test))
print('cross validation score',cross_val_score(gnb,x,y,scoring='r2').mean()*100)

print('-------------------------------')
print('\n')

print('EVALUATION METRICS')
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('MAE',mean_absolute_error(target_test,pred_test))
print('MSE',mean_squared_error(target_test,pred_test))  
print('RMSE',np.sqrt(mean_squared_error(target_test,pred_test)))
print('\n')
# Out:
# ACCURACY
# Training accuracy 99.99972030491415
# Test Accuracy 49.90999679991002
# -------------------------------
#
#
# SCORES
# r2_score 0.49909996799910017
# cross validation score -132.99693184589617
# -------------------------------
#
#
# EVALUATION METRICS
# MAE 5.443657594333939
# MSE 45.52624735297067
# RMSE 6.747314084357617

# %% [markdown]
# #### Observation: Linear Regression model has better scores compared to other models, since it has goog training and testing accuracy, and the difference between test and training accuracy is very less.

# %% [markdown]
# # Comparing y_pred with y_test to check the model performance

# %%
pred_target = lr.predict(features_test)         #We make prediction for the x_test data, and compare the obtained pred_values 
                                            #with the actual y_test values to check our model performance
pred_target
# Out:
# array([[82.51698223],
#        [83.40922434],
#        [93.41456153],
#        [81.6197455 ],
#        [60.83013027],
#        [74.40782733]])

# %%
target_test
# Out:
#      W
# 21  83
# 13  76
# 0   95
# 27  79
# 24  63
# 3   76

# %%
plt.scatter(target_test,pred_target)
plt.xlabel('Actual W')
plt.ylabel('Predicted W')
plt.title('Actual no.of wins vs Model predicted')
plt.show()

# %%
sns.regplot(target_test,pred_test)

# %% [markdown]
# # Saving the model

# %%
import pickle
filename = 'baseball.pkl'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# # conclusion

# %%
loaded_model= pickle.load(open('baseball.pkl','rb'))
result = loaded_model.score(features_test,target_test)
print(result)
# Out:
# 0.8684292025690163

# %%
conclusion = pd.DataFrame([loaded_model.predict(features_test)[:], pred_test[:]], index=["Predicted","Original"])

conclusion
# Out:
#                                                            0
# Predicted  [[82.51698222721097], [83.40922433540521], [93...
# Original   [89.67525154968752, 79.36123801527391, 81.5270...
